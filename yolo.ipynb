# %% [markdown]
# ### Install dependencies:

# %%
# !pip install ultralytics opencv-python matplotlib

# %% [markdown]
# ### Create Your Dataset

# %%
# !python main/takepic.py

# %% [markdown]
# ### Assign labels to the images and store them in the "label" folder. you can label them using roboflow.

# %% [markdown]
# ### Train YOLOv8

# %%
# !yolo detect train model=yolov8n.pt data=sign_language.yaml epochs=100 imgsz=640

# %% [markdown]
# ### After training run the model

# %%
# !python main/live_camera.py
